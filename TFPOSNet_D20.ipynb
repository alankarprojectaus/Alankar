# %% [markdown]
# ## 📦 Cell 1 — Install Dependencies

# %%
# !pip install stanza -q
# !pip install iterative-stratification -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 21.4 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 773.7/773.7 kB 44.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.7/418.7 kB 28.9 MB/s eta 0:00:00

# %%
import kagglehub
path = kagglehub.dataset_download("mithramadapa25/ngram-20k")
print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/datasets/mithramadapa25/ngram-20k

# %% [markdown]
# ## ⏱ Cell 2 — Runtime Tracker Start

# %%
import time
training_start_time = time.time()
print("⏱ Runtime tracker started.")
# Out:
# ⏱ Runtime tracker started.

# %% [markdown]
# ## 📚 Cell 3 — Imports

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, f1_score, multilabel_confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import stanza
from scipy.sparse import hstack, csr_matrix
from tqdm import tqdm

print("TensorFlow Version:", tf.__version__)
print("GPU Available:", tf.config.list_physical_devices('GPU'))
# Out:
# 2026-04-21 13:01:18.089133: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776776478.302311      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776776478.360767      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776776478.815725      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776776478.815768      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776776478.815771      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776776478.815774      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow Version: 2.19.0
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %% [markdown]
# ## ⚙️ Cell 4 — Configuration
# > **Change your hyperparameters here.**

# %%
# ================================
# CONFIGURATION — CHANGE SETTINGS HERE
# ================================
EPOCHS        = 30
BATCH_SIZE    = 64
LEARNING_RATE = 0.001
THRESHOLD     = 0.5
TEST_SIZE     = 0.2
RANDOM_STATE  = 42
# ================================

print(f"Epochs: {EPOCHS} | Batch: {BATCH_SIZE} | LR: {LEARNING_RATE} | Threshold: {THRESHOLD}")
# Out:
# Epochs: 30 | Batch: 64 | LR: 0.001 | Threshold: 0.5

# %% [markdown]
# ## 📂 Cell 5 — Load Dataset

# %%
data_path = '/kaggle/input/datasets/mithramadapa25/ngram-20k/n_gram_20k.xlsx'
data = pd.read_excel(data_path)

text_col  = 'Text'
label_col = 'Detected Alankars'
data[label_col] = data[label_col].fillna("")

print(f"Dataset shape: {data.shape}")
print(f"Columns: {list(data.columns)}")
data.head()
# Out:
# Dataset shape: (20342, 5)
# Columns: ['Poem ID', 'Title', 'Line Group', 'Text', 'Detected Alankars']
#    Poem ID                    Title    Line Group  \
# 0        1  नया रास्ता (Naya Rasta)  Lines 1 to 1
# 1        1  नया रास्ता (Naya Rasta)  Lines 2 to 2
# 2        1  नया रास्ता (Naya Rasta)  Lines 3 to 3
# 3        1  नया रास्ता (Naya Rasta)  Lines 4 to 4
# 4        1  नया रास्ता (Naya Rasta)  Lines 5 to 5
#
#                                         Text             Detected Alankars
# 0    जब सारे जाने हुए रास्ते बंद हो जाते हैं  Yamak, Anupras, Upma, Roopak
# 1  तो आदमी एक नए रास्ते के बारे में सोचता है                        Roopak
# 2    एक नए रास्ते के बारे में सोचता हुआ आदमी
# 3          एक नए प्रयास के बारे में सोचता है                        Roopak
# 4    एक नए प्रयास के बारे में सोचता हुआ आदमी

# %% [markdown]
# ## 🏷️ Cell 6 — Preprocess Labels (MultiLabelBinarizer)

# %%
labels_list = data[label_col].apply(
    lambda x: [l.strip() for l in str(x).split(',') if l.strip()]
)

mlb = MultiLabelBinarizer()
y   = mlb.fit_transform(labels_list).astype(np.float32)

num_classes = len(mlb.classes_)
print("Detected Alankar Classes:", mlb.classes_)
print("Number of Classes:", num_classes)
print("Label matrix shape:", y.shape)
# Out:
# Detected Alankar Classes: ['Anupras' 'Roopak' 'Shlesh' 'Upma' 'Utpreksha' 'Virodhbhas' 'Yamak']
# Number of Classes: 7
# Label matrix shape: (20342, 7)

# %% [markdown]
# ## 🔤 Cell 7 — TF-IDF Vectorization

# %%
vectorizer = TfidfVectorizer(
    ngram_range=(1, 3),
    max_features=50000
)

X_tfidf = vectorizer.fit_transform(data[text_col].astype(str))
print("TF-IDF Feature shape:", X_tfidf.shape)
# Out:
# TF-IDF Feature shape: (20342, 4724)

# %% [markdown]
# ## 💾 Cell 8 — Save TF-IDF Sample to Excel

# %%
tfidf_sample_size   = 100
tfidf_sample        = X_tfidf[:, :tfidf_sample_size].toarray()
tfidf_feature_names = vectorizer.get_feature_names_out()[:tfidf_sample_size]

tfidf_df         = pd.DataFrame(tfidf_sample, columns=tfidf_feature_names)
tfidf_excel_path = "/kaggle/working/TFIDF_Features_Sample_100.xlsx"
tfidf_df.to_excel(tfidf_excel_path, index=False)
print("✅ TF-IDF sample saved to Excel:", tfidf_excel_path)
# Out:
# ✅ TF-IDF sample saved to Excel: /kaggle/working/TFIDF_Features_Sample_100.xlsx

# %% [markdown]
# ## 🔡 Cell 9 — POS Feature Extraction (Stanza Hindi)
# > Uses cache if already computed. First run will download the Hindi model.

# %%
## 🔡 Cell 9 — POS Feature Extraction (Optimized for T4 GPU)
upos_list = ['ADJ','ADP','ADV','AUX','CCONJ','DET','INTJ','NOUN','NUM','PART','PRON','PROPN','PUNCT','SCONJ','SYM','VERB','X']
upos2idx = {tag: i for i, tag in enumerate(upos_list)}
pos_cache = "/kaggle/working/pos_features.npy"
N = len(data)

if os.path.exists(pos_cache):
    pos_matrix = np.load(pos_cache)
    print("✅ Loaded cached POS features")
else:
    stanza.download('hi', processors='tokenize,pos', verbose=False)

    # On T4, use_gpu=True works perfectly!
    nlp = stanza.Pipeline(
        'hi',
        processors='tokenize,pos',
        use_gpu=True, 
        tokenize_batch_size=256, # Increased for T4
        pos_batch_size=256,      # Increased for T4
        verbose=False
    )

    texts = data[text_col].astype(str).tolist()
    pos_matrix = np.zeros((N, len(upos_list)), dtype=np.float32)
    
    # Process in large batches to saturate the T4 GPU
    batch_size_pos = 512 

    for start in tqdm(range(0, N, batch_size_pos), desc="GPU POS Extraction"):
        end = min(start + batch_size_pos, N)
        docs = nlp.bulk_process(texts[start:end])

        for i, doc in enumerate(docs):
            vec = np.zeros(len(upos_list))
            for sent in doc.sentences:
                for word in sent.words:
                    if word.upos in upos2idx:
                        vec[upos2idx[word.upos]] += 1
            total = vec.sum()
            pos_matrix[start + i] = vec / total if total > 0 else vec

    np.save(pos_cache, pos_matrix)
    print("✅ GPU POS extraction complete.")
# Out:
# GPU POS Extraction: 100%|██████████| 40/40 [05:56<00:00,  8.90s/it]
# ✅ GPU POS extraction complete.

# %% [markdown]
# ## 💾 Cell 10 — Save POS Features to Excel

# %%
pos_df         = pd.DataFrame(pos_matrix, columns=upos_list)
pos_excel_path = "/kaggle/working/POS_Features.xlsx"
pos_df.to_excel(pos_excel_path, index=False)
print("✅ POS features saved to Excel:", pos_excel_path)
# Out:
# ✅ POS features saved to Excel: /kaggle/working/POS_Features.xlsx

# %% [markdown]
# ## 🔗 Cell 11 — Combine TF-IDF + POS Features

# %%
pos_sparse = csr_matrix(pos_matrix)
X_combined = hstack([X_tfidf, pos_sparse]).tocsr()
print("Combined Feature shape:", X_combined.shape)
# Out:
# Combined Feature shape: (20342, 4741)

# %% [markdown]
# ## 💾 Cell 12 — Save Combined Feature Sample to Excel

# %%
combined_sample_size   = 100
combined_sample        = X_combined[:, :combined_sample_size].toarray()
combined_feature_names = vectorizer.get_feature_names_out()[:combined_sample_size]

combined_df         = pd.DataFrame(combined_sample, columns=combined_feature_names)
combined_excel_path = "/kaggle/working/Combined_Features_Sample_100.xlsx"
combined_df.to_excel(combined_excel_path, index=False)
print("✅ Combined feature sample saved to Excel:", combined_excel_path)
# Out:
# ✅ Combined feature sample saved to Excel: /kaggle/working/Combined_Features_Sample_100.xlsx

# %% [markdown]
# ## ✂️ Cell 13 — Train / Validation Split

# %%
# ── Stratified 80/20 Train / Validation Split ──────────────────────────────
# scikit-learn's train_test_split only supports stratify on 1-D arrays,
# so we use iterative-stratification for multi-label data.
# If the package isn't installed, we fall back to a simple random split.
try:
    from iterstrat.ml_stratifiers import MultilabelStratifiedShuffleSplit
    msss = MultilabelStratifiedShuffleSplit(
        n_splits=1, test_size=TEST_SIZE, random_state=RANDOM_STATE
    )
    train_idx, val_idx = next(msss.split(np.arange(N), y))
    print("✅ Using MultilabelStratifiedShuffleSplit (label-aware 80/20 split)")
except ImportError:
    print("⚠️  iterstrat not found — install with: pip install iterative-stratification")
    print("   Falling back to random split.")
    train_idx, val_idx = train_test_split(
        np.arange(N), test_size=TEST_SIZE, random_state=RANDOM_STATE
    )

X_train, y_train = X_combined[train_idx], y[train_idx]
X_val,   y_val   = X_combined[val_idx],   y[val_idx]

print(f"Train samples : {X_train.shape[0]}  ({X_train.shape[0]/N*100:.1f}%)")
print(f"Val   samples : {X_val.shape[0]}  ({X_val.shape[0]/N*100:.1f}%)")

# Show per-label distribution to verify stratification
print("\nPer-label positive-sample counts:")
label_df = pd.DataFrame({
    'Label'     : mlb.classes_,
    'Train (pos)': y_train.sum(axis=0).astype(int),
    'Val   (pos)': y_val.sum(axis=0).astype(int),
})
label_df['Val %'] = (label_df['Val   (pos)'] /
                     (label_df['Train (pos)'] + label_df['Val   (pos)']) * 100).round(1)
print(label_df.to_string(index=False))
# Out:
# ✅ Using MultilabelStratifiedShuffleSplit (label-aware 80/20 split)
# Train samples : 16273  (80.0%)
# Val   samples : 4069  (20.0%)
#
# Per-label positive-sample counts:
#      Label  Train (pos)  Val   (pos)  Val %
#    Anupras        15533         3884   20.0
#     Roopak        14459         3616   20.0
#     Shlesh         5711         1428   20.0
#       Upma        14631         3658   20.0
#  Utpreksha         5281         1320   20.0
# Virodhbhas         4631         1158   20.0
#      Yamak        15201         3801   20.0

# %% [markdown]
# ## ⚡ Cell 14 — Sparse → TensorFlow Dataset

# %%
def sparse_to_dataset(X, y, batch_size=64, shuffle=False, label_weights=None):
    """Convert sparse X + dense y to a tf.data.Dataset.
    
    If label_weights (shape: num_classes) is supplied, each sample receives
    a scalar weight = mean of the weights of its positive labels.  This
    implements cost-sensitive learning for multi-label classification.
    """
    idx = np.arange(X.shape[0])
    if shuffle:
        np.random.shuffle(idx)

    use_weights = label_weights is not None

    def gen():
        for i in range(0, len(idx), batch_size):
            b    = idx[i:i + batch_size]
            xb   = X[b].toarray().astype(np.float32)
            yb   = y[b]
            if use_weights:
                # sample weight = mean weight over the positive labels of that sample
                sw = np.array([
                    label_weights[yb[j].astype(bool)].mean()
                    if yb[j].sum() > 0 else 1.0
                    for j in range(len(b))
                ], dtype=np.float32)
                yield xb, yb, sw
            else:
                yield xb, yb

    if use_weights:
        sig = (
            tf.TensorSpec((None, X.shape[1]), tf.float32),
            tf.TensorSpec((None, y.shape[1]), tf.float32),
            tf.TensorSpec((None,),            tf.float32),
        )
    else:
        sig = (
            tf.TensorSpec((None, X.shape[1]), tf.float32),
            tf.TensorSpec((None, y.shape[1]), tf.float32),
        )

    return tf.data.Dataset.from_generator(gen, output_signature=sig)

# NOTE: datasets are rebuilt AFTER class weights are computed (Cell 15).
# Placeholder datasets without weights — overwritten below.
train_ds = sparse_to_dataset(X_train, y_train, batch_size=BATCH_SIZE, shuffle=True).prefetch(tf.data.AUTOTUNE)
val_ds   = sparse_to_dataset(X_val,   y_val,   batch_size=BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
print("✅ TensorFlow dataset helper defined (sample_weight support added).")
# Out:
# ✅ TensorFlow dataset helper defined (sample_weight support added).
# I0000 00:00:1776776940.827344      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3649 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1776776940.832444      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %% [markdown]
# ## 🏗️ Cell 15 — Build Model

# %%
import tensorflow as tf
from tensorflow.keras import backend as K  # <--- THIS FIXES THE NAMEERROR
from tensorflow.keras import mixed_precision
import gc

# 1. Clear memory and enable Mixed Precision
K.clear_session()
gc.collect()

# This helps the T4 GPU process large vectors more efficiently
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_global_policy(policy)

# 2. Build the Model
model = Sequential([
    Input(shape=(X_combined.shape[1],)),
    Dense(128, activation='relu'), 
    Dropout(0.5),
    Dense(64, activation='relu'),
    Dropout(0.4),
    # The output layer must stay float32 for classification stability
    Dense(num_classes, activation='sigmoid', dtype='float32') 
])

model.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

print("✅ Keras backend initialized and Mixed Precision enabled.")
# Out:
# ✅ Keras backend initialized and Mixed Precision enabled.

# %% [markdown]
# ## 🔔 Cell 16 — Define Callbacks

# %%
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=7,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=3,
        min_lr=1e-6,
        verbose=1
    ),
    ModelCheckpoint(
        filepath='/kaggle/working/best_model.keras',
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    )
]

print("✅ Callbacks defined: EarlyStopping | ReduceLROnPlateau | ModelCheckpoint")
# Out:
# ✅ Callbacks defined: EarlyStopping | ReduceLROnPlateau | ModelCheckpoint

# %% [markdown]
# ## 🚀 Cell 17 — Train Model

# %%
# ── 1. Initialize and Boost Weights ───────────────────────────────────────
# Calculate base weights to handle class imbalance in your 62k dataset
label_counts = y_train.sum(axis=0)
# Standard inverse frequency formula
label_weights = np.where(label_counts > 0, (len(y_train) / (num_classes * label_counts)), 1.0)

# Now apply your specific boosts for the paper
# Indexing: 5=Virodhbhas, 4=Utpreksha, 2=Shlesh
label_weights[5] = 5.0  # High penalty for missing Virodhbhas
label_weights[4] = 4.0  # High penalty for missing Utpreksha
label_weights[2] = 4.0  # Moderate boost for Shlesh

print("✅ label_weights defined and boosted.")

# ── 2. Rebuild datasets with BATCH_SIZE 16 ──────────────────────────────────
train_ds = sparse_to_dataset(
    X_train, y_train,
    batch_size=BATCH_SIZE,
    shuffle=True,
    label_weights=label_weights
).prefetch(tf.data.AUTOTUNE)

val_ds = sparse_to_dataset(
    X_val, y_val,
    batch_size=BATCH_SIZE,
    label_weights=label_weights
).prefetch(tf.data.AUTOTUNE)

print(f"✅ Datasets rebuilt (Batch Size: {BATCH_SIZE}).")

# ── 3. Start Training ──────────────────────────────────────────────────────
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)
# Out:
# ✅ label_weights defined and boosted.
# ✅ Datasets rebuilt (Batch Size: 64).
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776776945.374867     120 service.cc:152] XLA service 0x79370004ac40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1776776945.374941     120 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1776776945.374953     120 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1776776945.739208     120 cuda_dnn.cc:529] Loaded cuDNN version 91002
#      37/Unknown 4s 4ms/step - accuracy: 0.1156 - loss: 0.5656
# I0000 00:00:1776776948.000089     120 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#     255/Unknown 7s 13ms/step - accuracy: 0.2226 - loss: 0.3609
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 1: val_loss improved from inf to 0.08799, saving model to /kaggle/working/best_model.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.2231 - loss: 0.3604 - val_accuracy: 0.7270 - val_loss: 0.0880 - learning_rate: 0.0010
# Epoch 2/30
# 252/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4927 - loss: 0.1093
# Epoch 2: val_loss improved from 0.08799 to 0.05354, saving model to /kaggle/working/best_model.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4928 - loss: 0.1091 - val_accuracy: 0.7400 - val_loss: 0.0535 - learning_rate: 0.0010
# Epoch 3/30
# 254/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5345 - loss: 0.0766
# Epoch 3: val_loss improved from 0.05354 to 0.04252, saving model to /kaggle/working/best_model.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5348 - loss: 0.0766 - val_accuracy: 0.9405 - val_loss: 0.0425 - learning_rate: 0.0010
# Epoch 4/30
# 250/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6463 - loss: 0.0656
# Epoch 4: val_loss improved from 0.04252 to 0.03781, saving model to /kaggle/working/best_model.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6465 - loss: 0.0656 - val_accuracy: 0.9132 - val_loss: 0.0378 - learning_rate: 0.0010
# Epoch 5/30
# 243/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6661 - loss: 0.0571
# Epoch 5: val_loss improved from 0.03781 to 0.03390, saving model to /kaggle/working/best_model.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6664 - loss: 0.0570 - val_accuracy: 0.9022 - val_loss: 0.0339 - learning_rate: 0.0010
# Epoch 6/30
# 254/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6842 - loss: 0.0513
# Epoch 6: val_loss improved from 0.03390 to 0.03097, saving model to /kaggle/working/best_model.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6842 - loss: 0.0513 - val_accuracy: 0.9002 - val_loss: 0.0310 - learning_rate: 0.0010
# Epoch 7/30
# 249/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7129 - loss: 0.0457
# Epoch 7: val_loss improved from 0.03097 to 0.02780, saving model to /kaggle/working/best_model.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7130 - loss: 0.0456 - val_accuracy: 0.8801 - val_loss: 0.0278 - learning_rate: 0.0010
# Epoch 8/30
# 251/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7303 - loss: 0.0425
# Epoch 8: val_loss improved from 0.02780 to 0.02524, saving model to /kaggle/working/best_model.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7305 - loss: 0.0425 - val_accuracy: 0.8916 - val_loss: 0.0252 - learning_rate: 0.0010
# Epoch 9/30
# 246/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7498 - loss: 0.0396
# Epoch 9: val_loss improved from 0.02524 to 0.02385, saving model to /kaggle/working/best_model.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7498 - loss: 0.0395 - val_accuracy: 0.8779 - val_loss: 0.0238 - learning_rate: 0.0010
# Epoch 10/30
# 251/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7376 - loss: 0.0372
# Epoch 10: val_loss improved from 0.02385 to 0.02366, saving model to /kaggle/working/best_model.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7374 - loss: 0.0372 - val_accuracy: 0.8444 - val_loss: 0.0237 - learning_rate: 0.0010
# Epoch 11/30
# 249/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7328 - loss: 0.0348
# Epoch 11: val_loss improved from 0.02366 to 0.02172, saving model to /kaggle/working/best_model.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7329 - loss: 0.0347 - val_accuracy: 0.8435 - val_loss: 0.0217 - learning_rate: 0.0010
# Epoch 12/30
# 244/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7286 - loss: 0.0326
# Epoch 12: val_loss did not improve from 0.02172
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7284 - loss: 0.0326 - val_accuracy: 0.8380 - val_loss: 0.0220 - learning_rate: 0.0010
# Epoch 13/30
# 254/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7025 - loss: 0.0310
# Epoch 13: val_loss improved from 0.02172 to 0.02010, saving model to /kaggle/working/best_model.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7025 - loss: 0.0310 - val_accuracy: 0.8435 - val_loss: 0.0201 - learning_rate: 0.0010
# Epoch 14/30
# 242/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7201 - loss: 0.0303
# Epoch 14: val_loss improved from 0.02010 to 0.02000, saving model to /kaggle/working/best_model.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7200 - loss: 0.0302 - val_accuracy: 0.8098 - val_loss: 0.0200 - learning_rate: 0.0010
# Epoch 15/30
# 244/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7089 - loss: 0.0301
# Epoch 15: val_loss improved from 0.02000 to 0.01944, saving model to /kaggle/working/best_model.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7091 - loss: 0.0301 - val_accuracy: 0.7928 - val_loss: 0.0194 - learning_rate: 0.0010
# Epoch 16/30
# 244/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7057 - loss: 0.0275
# Epoch 16: val_loss improved from 0.01944 to 0.01908, saving model to /kaggle/working/best_model.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7058 - loss: 0.0275 - val_accuracy: 0.7982 - val_loss: 0.0191 - learning_rate: 0.0010
# Epoch 17/30
# 247/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7078 - loss: 0.0251
# Epoch 17: val_loss improved from 0.01908 to 0.01813, saving model to /kaggle/working/best_model.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7076 - loss: 0.0251 - val_accuracy: 0.7955 - val_loss: 0.0181 - learning_rate: 0.0010
# Epoch 18/30
# 246/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7115 - loss: 0.0241
# Epoch 18: val_loss improved from 0.01813 to 0.01787, saving model to /kaggle/working/best_model.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7111 - loss: 0.0241 - val_accuracy: 0.7442 - val_loss: 0.0179 - learning_rate: 0.0010
# Epoch 19/30
# 247/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6927 - loss: 0.0252
# Epoch 19: val_loss did not improve from 0.01787
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6931 - loss: 0.0251 - val_accuracy: 0.7803 - val_loss: 0.0185 - learning_rate: 0.0010
# Epoch 20/30
# 242/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7044 - loss: 0.0234
# Epoch 20: val_loss improved from 0.01787 to 0.01712, saving model to /kaggle/working/best_model.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7040 - loss: 0.0233 - val_accuracy: 0.7461 - val_loss: 0.0171 - learning_rate: 0.0010
# Epoch 21/30
# 245/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6958 - loss: 0.0223
# Epoch 21: val_loss did not improve from 0.01712
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6957 - loss: 0.0223 - val_accuracy: 0.7250 - val_loss: 0.0172 - learning_rate: 0.0010
# Epoch 22/30
# 249/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6997 - loss: 0.0214
# Epoch 22: val_loss improved from 0.01712 to 0.01699, saving model to /kaggle/working/best_model.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6997 - loss: 0.0213 - val_accuracy: 0.7483 - val_loss: 0.0170 - learning_rate: 0.0010
# Epoch 23/30
# 253/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6952 - loss: 0.0214
# Epoch 23: val_loss did not improve from 0.01699
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6952 - loss: 0.0214 - val_accuracy: 0.7535 - val_loss: 0.0172 - learning_rate: 0.0010
# Epoch 24/30
# 254/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6966 - loss: 0.0208
# Epoch 24: val_loss did not improve from 0.01699
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6966 - loss: 0.0208 - val_accuracy: 0.7877 - val_loss: 0.0172 - learning_rate: 0.0010
# Epoch 25/30
# 249/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7242 - loss: 0.0206
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 25: val_loss did not improve from 0.01699
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7239 - loss: 0.0206 - val_accuracy: 0.7589 - val_loss: 0.0174 - learning_rate: 0.0010
# Epoch 26/30
# 251/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7073 - loss: 0.0195
# Epoch 26: val_loss improved from 0.01699 to 0.01623, saving model to /kaggle/working/best_model.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7072 - loss: 0.0195 - val_accuracy: 0.7247 - val_loss: 0.0162 - learning_rate: 5.0000e-04
# Epoch 27/30
# 254/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7026 - loss: 0.0177
# Epoch 27: val_loss improved from 0.01623 to 0.01553, saving model to /kaggle/working/best_model.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7026 - loss: 0.0177 - val_accuracy: 0.7476 - val_loss: 0.0155 - learning_rate: 5.0000e-04
# Epoch 28/30
# 245/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7163 - loss: 0.0183
# Epoch 28: val_loss did not improve from 0.01553
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7163 - loss: 0.0182 - val_accuracy: 0.7567 - val_loss: 0.0159 - learning_rate: 5.0000e-04
# Epoch 29/30
# 242/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7175 - loss: 0.0169
# Epoch 29: val_loss did not improve from 0.01553
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7174 - loss: 0.0168 - val_accuracy: 0.7655 - val_loss: 0.0157 - learning_rate: 5.0000e-04
# Epoch 30/30
# 247/255 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7244 - loss: 0.0161
# Epoch 30: val_loss improved from 0.01553 to 0.01540, saving model to /kaggle/working/best_model.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7242 - loss: 0.0160 - val_accuracy: 0.7835 - val_loss: 0.0154 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 30.

# %% [markdown]
# ## 📊 Cell 18 — Evaluation: Classification Report + F1 + Hamming Accuracy

# %%
# ════════════════════════════════════════════════════════════════
# Cell 18 — Evaluation on Validation (Test) Data
# ════════════════════════════════════════════════════════════════
from sklearn.metrics import classification_report, f1_score, accuracy_score
import numpy as np

print("Generating predictions for the Validation set...")

# 1. Generate Raw Probabilities from the validation dataset
# This is the "Testing" phase.
y_pred_proba = model.predict(val_ds, verbose=1)

# 2. Convert probabilities to binary (0 or 1) using your Threshold
# THRESHOLD is usually 0.5 (defined in Cell 4)
y_pred = (y_pred_proba >= THRESHOLD).astype(int)

# 3. Print the Classification Report
# This shows Precision, Recall, and F1 for each of your 7 Alankars
print("\n✅ Classification Report (Testing Data):\n")
print(classification_report(y_val, y_pred, target_names=mlb.classes_, zero_division=0))

# 4. Calculate Key Metrics
macro_f1 = f1_score(y_val, y_pred, average='macro', zero_division=0)
subset_acc = accuracy_score(y_val, y_pred) # Exact matches only
hamming_loss = np.mean(y_val != y_pred)    # Average error rate

# ---- Display Results ----
print("="*45)
print(f"Macro F1 Score:   {macro_f1:.4f}")
print(f"Subset Accuracy:  {subset_acc:.4f} ({subset_acc * 100:.2f}%)")
print(f"Hamming Accuracy: {1.0 - hamming_loss:.4f}")
print("="*45)
# Out:
# Generating predictions for the Validation set...
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
#
# ✅ Classification Report (Testing Data):
#
#               precision    recall  f1-score   support
#
#      Anupras       0.98      0.99      0.98      3884
#       Roopak       0.99      1.00      0.99      3616
#       Shlesh       0.99      0.99      0.99      1428
#         Upma       0.99      0.99      0.99      3658
#    Utpreksha       0.98      1.00      0.99      1320
#   Virodhbhas       1.00      1.00      1.00      1158
#        Yamak       0.98      0.99      0.98      3801
#
#    micro avg       0.99      0.99      0.99     18865
#    macro avg       0.99      0.99      0.99     18865
# weighted avg       0.99      0.99      0.99     18865
#  samples avg       0.96      0.97      0.96     18865
#
# =============================================
# Macro F1 Score:   0.9897
# Subset Accuracy:  0.9243 (92.43%)
# Hamming Accuracy: 0.9853
# =============================================

# %% [markdown]
# ## 🌡️ Cell 19 — Correlation Heatmap (Predicted Labels)

# %%
# ════════════════════════════════════════════════════════════════
# Cell 19 — Multi-label Prediction Heatmap (Corrected for Test Data)
# ════════════════════════════════════════════════════════════════
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 1. Ensure arrays are binary and use the test/validation set
y_true_arr = np.array(y_val) 
y_pred_arr = (np.array(y_pred) >= THRESHOLD).astype(int)

# 2. Initialize the matrix (7x7 for your Alankar classes)
num_classes = len(mlb.classes_)
multilabel_cm = np.zeros((num_classes, num_classes))

# 3. Explicit intersection count (Row = Actual, Column = Predicted)
# This ensures row-wise counts match your actual test sample totals
for i in range(num_classes):       # i represents True Label index
    for j in range(num_classes):   # j represents Predicted Label index
        # Count samples where label i was TRUE and label j was PREDICTED
        intersection = np.sum((y_true_arr[:, i] == 1) & (y_pred_arr[:, j] == 1))
        multilabel_cm[i, j] = intersection

# 4. Plotting the Heatmap
plt.figure(figsize=(12, 9))
sns.heatmap(
    multilabel_cm, 
    annot=True, 
    fmt=".0f", 
    cmap="magma", 
    xticklabels=mlb.classes_, 
    yticklabels=mlb.classes_,
    square=True,
    cbar_kws={"label": "Number of Samples"}
)

plt.title("Multi-label Prediction Heatmap (Test Data Accuracy)", fontsize=14, pad=20, fontweight='bold')
plt.xlabel("Predicted Alankars", fontsize=12)
plt.ylabel("True (Actual) Alankars", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Save the corrected version
plt.savefig("/kaggle/working/corrected_test_heatmap.png", dpi=300)
plt.show()

print("✅ Corrected heatmap using explicit intersection counts is complete.")
# Out:
# ✅ Corrected heatmap using explicit intersection counts is complete.

# %% [markdown]
# ## 🔲 Cell 20 — Confusion Matrix Heatmaps (Per Label — Test Data)
# > Each cell shows: **count** and **row percentage**.

# %%
print("Generating Confusion Matrix Heatmaps (based on test/validation data)...")
conf_matrices = multilabel_confusion_matrix(y_val, y_pred)

for i, label in enumerate(mlb.classes_):
    cm = conf_matrices[i]
    cm_df = pd.DataFrame(
        cm,
        index=["Actual 0", "Actual 1"],
        columns=["Predicted 0", "Predicted 1"]
    )
    csv_path = f"/kaggle/working/confusion_matrix_{label}.csv"
    cm_df.to_csv(csv_path)

    # Annotation: count + row percentage
    cm_sum  = cm.sum(axis=1, keepdims=True)
    cm_perc = np.divide(cm.astype(float), cm_sum, where=cm_sum != 0) * 100
    annot   = np.array([
        [f"{v}\n({cm_perc[r, c]:.1f}%)" for c, v in enumerate(row)]
        for r, row in enumerate(cm)
    ])

    plt.figure(figsize=(5, 4))
    sns.heatmap(
        cm,
        annot=annot,
        fmt="",
        cmap="Blues",
        xticklabels=["Predicted 0", "Predicted 1"],
        yticklabels=["Actual 0", "Actual 1"]
    )
    plt.title(f"Confusion Matrix (Test Data) - {label}")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.tight_layout()
    png_path = f"/kaggle/working/confusion_matrix_{label}.png"
    plt.savefig(png_path, dpi=300)
    plt.show()

print("✅ Confusion matrices (test data) saved as PNG and CSV.")
# Out:
# Generating Confusion Matrix Heatmaps (based on test/validation data)...
# ✅ Confusion matrices (test data) saved as PNG and CSV.

# %% [markdown]
# ## 📈 Cell 21 — Plot Training History (Accuracy & Loss)

# %%
# ═══════════════════════════════════════════════════════════
# Cell 21 — Training History: Accuracy & Loss Graphs
# ═══════════════════════════════════════════════════════════
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

epochs_ran  = range(1, len(history.history['loss']) + 1)
train_loss  = history.history['loss']
val_loss    = history.history['val_loss']
train_acc   = history.history['accuracy']
val_acc     = history.history['val_accuracy']

# Best epoch (lowest val_loss)
best_epoch  = int(np.argmin(val_loss)) + 1

fig = plt.figure(figsize=(14, 5))
gs  = gridspec.GridSpec(1, 2, figure=fig, wspace=0.35)

# ── Left: Loss ──────────────────────────────────────────────
ax1 = fig.add_subplot(gs[0])
ax1.plot(epochs_ran, train_loss, 'b-o',  markersize=4, linewidth=1.8, label='Train loss')
ax1.plot(epochs_ran, val_loss,   'r--s', markersize=4, linewidth=1.8, label='Val loss')
ax1.axvline(best_epoch, color='green', linestyle=':', linewidth=1.5,
            label=f'Best epoch ({best_epoch})')
ax1.fill_between(epochs_ran, train_loss, val_loss, alpha=0.07, color='purple',
                 label='Gap (overfit region)')
ax1.set_title('Training & Validation Loss', fontsize=13, pad=10)
ax1.set_xlabel('Epoch', fontsize=11)
ax1.set_ylabel('Binary Cross-Entropy Loss', fontsize=11)
ax1.legend(fontsize=9)
ax1.grid(True, alpha=0.3)
ax1.set_xlim(1, len(epochs_ran))

# Annotate best val_loss
best_val_loss = val_loss[best_epoch - 1]
ax1.annotate(
    f'Best: {best_val_loss:.4f}',
    xy=(best_epoch, best_val_loss),
    xytext=(best_epoch + max(1, len(epochs_ran)//8), best_val_loss + 0.01),
    arrowprops=dict(arrowstyle='->', color='green'),
    fontsize=9, color='green'
)

# ── Right: Accuracy ─────────────────────────────────────────
ax2 = fig.add_subplot(gs[1])
ax2.plot(epochs_ran, train_acc, 'b-o',  markersize=4, linewidth=1.8, label='Train accuracy')
ax2.plot(epochs_ran, val_acc,   'r--s', markersize=4, linewidth=1.8, label='Val accuracy')
ax2.axvline(best_epoch, color='green', linestyle=':', linewidth=1.5,
            label=f'Best epoch ({best_epoch})')
ax2.fill_between(epochs_ran, train_acc, val_acc, alpha=0.07, color='orange',
                 label='Gap')
ax2.set_title('Training & Validation Accuracy', fontsize=13, pad=10)
ax2.set_xlabel('Epoch', fontsize=11)
ax2.set_ylabel('Accuracy', fontsize=11)
ax2.legend(fontsize=9)
ax2.grid(True, alpha=0.3)
ax2.set_xlim(1, len(epochs_ran))
ax2.set_ylim(0, 1.05)

# Annotate best val_accuracy
best_val_acc = val_acc[best_epoch - 1]
ax2.annotate(
    f'Best: {best_val_acc:.4f}',
    xy=(best_epoch, best_val_acc),
    xytext=(best_epoch + max(1, len(epochs_ran)//8), best_val_acc - 0.06),
    arrowprops=dict(arrowstyle='->', color='green'),
    fontsize=9, color='green'
)

plt.suptitle('Model Training History', fontsize=15, fontweight='bold', y=1.02)
plt.savefig('/kaggle/working/training_history.png', dpi=300, bbox_inches='tight')
plt.show()

print("✅ Training history graphs saved to /kaggle/working/training_history.png")
print(f"   Best epoch        : {best_epoch}")
print(f"   Best val loss     : {best_val_loss:.4f}")
print(f"   Best val accuracy : {best_val_acc:.4f}")
# Out:
# ✅ Training history graphs saved to /kaggle/working/training_history.png
#    Best epoch        : 30
#    Best val loss     : 0.0154
#    Best val accuracy : 0.7835

# %% [markdown]
# ## ⏱ Cell 22 — Total Runtime & Output Summary

# %%
total_seconds = time.time() - training_start_time
hours   = int(total_seconds // 3600)
minutes = int((total_seconds % 3600) // 60)
seconds = int(total_seconds % 60)

print("\n" + "="*50)
print(f"⏱  TOTAL RUNTIME: {hours}h {minutes}m {seconds}s")
print("="*50)

print("\n✅ All outputs saved to /kaggle/working/")
print("   - best_model.keras")
print("   - TFIDF_Features_Sample_100.xlsx")
print("   - POS_Features.xlsx")
print("   - Combined_Features_Sample_100.xlsx")
print("   - multilabel_cooccurrence_heatmap.png  ← NEW")
print("   - per_label_rate_bar.png               ← NEW")
print("   - confusion_matrix_<label>.png / .csv")
print("   - training_history.png")
# Out:
# ==================================================
# ⏱  TOTAL RUNTIME: 0h 8m 41s
# ==================================================
#
# ✅ All outputs saved to /kaggle/working/
#    - best_model.keras
#    - TFIDF_Features_Sample_100.xlsx
#    - POS_Features.xlsx
#    - Combined_Features_Sample_100.xlsx
#    - multilabel_cooccurrence_heatmap.png  ← NEW
#    - per_label_rate_bar.png               ← NEW
#    - confusion_matrix_<label>.png / .csv
#    - training_history.png

# %% [markdown]
# ## 🔮 Cell 23 — Test on Unseen Data
# > Run this **AFTER** the model training completes. Predict Alankars on new, unseen Hindi text.

# %%
# ════════════════════════════════════════════════════════════════════════════════
# Cell 23 — Test on Unseen Data
# (Run this AFTER the model training completes)
# ════════════════════════════════════════════════════════════════════════════════

import numpy as np
import pandas as pd
from scipy.sparse import hstack, csr_matrix

# ════════════════════════════════════════════════════════════════════════════════
# ↓↓↓ REPLACE THESE WITH YOUR OWN UNSEEN HINDI SENTENCES ↓↓↓
# ════════════════════════════════════════════════════════════════════════════════
unseen_texts = [
    "उसका चेहरा चाँद जैसा उजाला है,",
    "मंद-मंद मुस्कान मन को भाया है,",
    "चंचल चितवन चुरा ले गई दिल को,",
    "उसकी बातें जैसे मधुर रस की धारा हैं,",
    "वह तो जीवन का सूरज बन आया है।"
]
# ════════════════════════════════════════════════════════════════════════════════

# ── Step 1: TF-IDF features (reuse trained vectorizer) ──
X_unseen_tfidf = vectorizer.transform(unseen_texts)
print(f"✅ TF-IDF shape: {X_unseen_tfidf.shape}")

# ── Step 2: POS features (reuse trained nlp pipeline) ──
unseen_pos  = np.zeros((len(unseen_texts), len(upos_list)), dtype=np.float32)
unseen_docs = nlp.bulk_process(unseen_texts)

for i, doc in enumerate(unseen_docs):
    vec = np.zeros(len(upos_list))
    for sent in doc.sentences:
        for word in sent.words:
            if word.upos in upos2idx:
                vec[upos2idx[word.upos]] += 1
    total = vec.sum()
    unseen_pos[i] = vec / total if total > 0 else vec

print(f"✅ POS shape: {unseen_pos.shape}")

# ── Step 3: Combine TF-IDF + POS ──
X_unseen = hstack([X_unseen_tfidf, csr_matrix(unseen_pos)]).toarray().astype(np.float32)
print(f"✅ Combined shape: {X_unseen.shape}")

# ── Step 4: Predict ──
proba  = model.predict(X_unseen, verbose=0)
y_pred_unseen = (proba >= THRESHOLD).astype(int)

# ── Step 5: Display results ──
print("\n" + "="*70)
print(" "*15 + "UNSEEN DATA — ALANKAR PREDICTIONS")
print("="*70)

for i, text in enumerate(unseen_texts):
    detected = [mlb.classes_[j] for j in range(len(mlb.classes_)) if y_pred_unseen[i][j] == 1]
    print(f"\n📝 Text     : {text}")
    print(f"🎯 Alankars : {detected if detected else ['None detected']}")
    prob_str = " | ".join(
        [f"{mlb.classes_[j]}: {proba[i][j]:.3f}" for j in range(len(mlb.classes_))]
    )
    print(f"📊 Proba    : {prob_str}")

print("\n" + "="*70)

# ── Step 6: Save to Excel ──
results_df = pd.DataFrame({
    "Text": unseen_texts,
    "Predicted Alankars": [
        ", ".join([mlb.classes_[j] for j in range(len(mlb.classes_)) if y_pred_unseen[i][j] == 1]) or "None"
        for i in range(len(unseen_texts))
    ]
})

# Add individual probability columns per class
for j, cls in enumerate(mlb.classes_):
    results_df[f"P({cls})"] = [round(float(proba[i][j]), 4) for i in range(len(unseen_texts))]

output_path = "/kaggle/working/unseen_predictions.xlsx"
results_df.to_excel(output_path, index=False)
print(f"\n✅ Predictions saved to: {output_path}")
print("\n" + results_df[["Text", "Predicted Alankars"]].to_string(index=False))
# Out:
# ✅ TF-IDF shape: (5, 4724)
# ✅ POS shape: (5, 17)
# ✅ Combined shape: (5, 4741)
#
# ======================================================================
#                UNSEEN DATA — ALANKAR PREDICTIONS
# ======================================================================
#
# 📝 Text     : उसका चेहरा चाँद जैसा उजाला है,
# 🎯 Alankars : ['None detected']
# 📊 Proba    : Anupras: 0.118 | Roopak: 0.074 | Shlesh: 0.001 | Upma: 0.045 | Utpreksha: 0.005 | Virodhbhas: 0.021 | Yamak: 0.034
#
# 📝 Text     : मंद-मंद मुस्कान मन को भाया है,
# 🎯 Alankars : ['None detected']
# 📊 Proba    : Anupras: 0.081 | Roopak: 0.013 | Shlesh: 0.005 | Upma: 0.021 | Utpreksha: 0.013 | Virodhbhas: 0.000 | Yamak: 0.040
#
# 📝 Text     : चंचल चितवन चुरा ले गई दिल को,
# 🎯 Alankars : ['None detected']
# 📊 Proba    : Anupras: 0.071 | Roopak: 0.004 | Shlesh: 0.001 | Upma: 0.041 | Utpreksha: 0.019 | Virodhbhas: 0.001 | Yamak: 0.034
#
# 📝 Text     : उसकी बातें जैसे मधुर रस की धारा हैं,
# 🎯 Alankars : ['None detected']
# 📊 Proba    : Anupras: 0.124 | Roopak: 0.029 | Shlesh: 0.012 | Upma: 0.062 | Utpreksha: 0.040 | Virodhbhas: 0.025 | Yamak: 0.059
#
# 📝 Text     : वह तो जीवन का सूरज बन आया है।
# 🎯 Alankars : ['None detected']
# 📊 Proba    : Anupras: 0.070 | Roopak: 0.005 | Shlesh: 0.001 | Upma: 0.019 | Utpreksha: 0.010 | Virodhbhas: 0.003 | Yamak: 0.027
#
# ======================================================================
#
# ✅ Predictions saved to: /kaggle/working/unseen_predictions.xlsx
#
#                                 Text Predicted Alankars
#       उसका चेहरा चाँद जैसा उजाला है,               None
#       मंद-मंद मुस्कान मन को भाया है,               None
#        चंचल चितवन चुरा ले गई दिल को,               None
# उसकी बातें जैसे मधुर रस की धारा हैं,               None
#        वह तो जीवन का सूरज बन आया है।               None
